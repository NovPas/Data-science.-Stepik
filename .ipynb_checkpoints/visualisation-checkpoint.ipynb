# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
students_performance = pd.read_csv('StudentsPerformance.csv')

# %%
students_performance
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
students_performance.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
students_performance['math score'].hist()
# Out:
# <AxesSubplot:>

# %%
students_performance.plot.scatter(y='math score', x='reading score')
# Out:
# <AxesSubplot:xlabel='reading score', ylabel='math score'>

# %%
sns.jointplot(data=students_performance, x="math score", y="reading score", hue="race/ethnicity")

# %%
sns.pairplot(data=students_performance, hue="gender")

# %% [markdown]
# # Tasks

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/income.csv')

# %%
df.income.plot()
# Out:
# <AxesSubplot:>

# %%
plt.plot(df.index, df.income)

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(x=df.index, y=df.income)
# Out:
# <AxesSubplot:ylabel='income'>

# %%
sns.lineplot(data=df)
# Out:
# <AxesSubplot:>

# %%
dataset_209770_6 = pd.read_csv('dataset_209770_6.txt', sep=' ')

# %%
dataset_209770_6
# Out:
#               x            y
# 0   1106.232004   408.120087
# 1    197.246006   495.605510
# 2   1218.599132   684.590253
# 3    893.285836   605.597073
# 4    998.037989  1406.747607
# ..          ...          ...
# 85   485.728548  1187.396928
# 86   210.881027   487.851163
# 87   523.285349  1190.989275
# 88   201.699281   502.267766
# 89   506.610628  1194.161125
#
# [90 rows x 2 columns]

# %%
dataset_209770_6.plot.scatter(y='y', x='x')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
genome_matrix = pd.read_csv('https://stepik.org/media/attachments/course/4852/genome_matrix.csv', index_col=0)

# %%
genome_matrix
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
g = sns.heatmap(genome_matrix, cmap="viridis") # ваш код для создания теплокарты, укажите параметр cmap="viridis" для той же цветовой схемы
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %%
dota_hero_stats = pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv', index_col=0)

# %%
dota_hero_stats
# Out:
#     attack_type   id  legs  localized_name                          name  \
# 0         Melee    1     2       Anti-Mage        npc_dota_hero_antimage
# 1         Melee    2     2             Axe             npc_dota_hero_axe
# 2        Ranged    3     4            Bane            npc_dota_hero_bane
# 3         Melee    4     2     Bloodseeker     npc_dota_hero_bloodseeker
# 4        Ranged    5     2  Crystal Maiden  npc_dota_hero_crystal_maiden
# ..          ...  ...   ...             ...                           ...
# 112       Melee  114     2     Monkey King     npc_dota_hero_monkey_king
# 113      Ranged  119     2     Dark Willow     npc_dota_hero_dark_willow
# 114       Melee  120     2       Pangolier       npc_dota_hero_pangolier
# 115      Ranged  121     2      Grimstroke      npc_dota_hero_grimstroke
# 116       Melee  129     2            Mars            npc_dota_hero_mars
#
#     primary_attr                                              roles
# ...

# %%
dota_hero_stats['roles_count'] = dota_hero_stats.roles.str.split().str.len()
dota_hero_stats
# Out:
#     attack_type   id  legs  localized_name                          name  \
# 0         Melee    1     2       Anti-Mage        npc_dota_hero_antimage
# 1         Melee    2     2             Axe             npc_dota_hero_axe
# 2        Ranged    3     4            Bane            npc_dota_hero_bane
# 3         Melee    4     2     Bloodseeker     npc_dota_hero_bloodseeker
# 4        Ranged    5     2  Crystal Maiden  npc_dota_hero_crystal_maiden
# ..          ...  ...   ...             ...                           ...
# 112       Melee  114     2     Monkey King     npc_dota_hero_monkey_king
# 113      Ranged  119     2     Dark Willow     npc_dota_hero_dark_willow
# 114       Melee  120     2       Pangolier       npc_dota_hero_pangolier
# 115      Ranged  121     2      Grimstroke      npc_dota_hero_grimstroke
# 116       Melee  129     2            Mars            npc_dota_hero_mars
#
#     primary_attr                                              roles  \
# ...

# %%
dota_hero_stats.roles_count.hist()
# dota_hero_stats.groupby(['roles_count']).roles_count.count()
# Out:
# <AxesSubplot:>

# %%
iris = pd.read_csv('https://stepik.org/media/attachments/course/4852/iris.csv', index_col=0)
iris
# Out:
#      sepal length  sepal width  petal length  petal width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
sns.kdeplot(data=iris)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.histplot(iris['sepal length'])
# Out:
# <AxesSubplot:xlabel='sepal length', ylabel='Count'>

# %%
sns.histplot(iris['sepal width'])
# Out:
# <AxesSubplot:xlabel='sepal width', ylabel='Count'>

# %%
sns.histplot(iris['petal length'])
# Out:
# <AxesSubplot:xlabel='petal length', ylabel='Count'>

# %%
sns.histplot(iris['petal width'])
# Out:
# <AxesSubplot:xlabel='petal width', ylabel='Count'>

# %%
sns.pairplot(iris, vars=iris.columns[:-1])

# %%
sns.violinplot(y=iris["petal length"])
# Out:
# <AxesSubplot:ylabel='petal length'>
