# %%
import pandas as pd
import numpy as np

# %%
dota_hero_stats = pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv')

# %%
dota_hero_stats
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
dota_hero_stats['legs'].value_counts()
# Out:
# 2    95
# 0    11
# 4     7
# 6     3
# 8     1
# Name: legs, dtype: int64

# %%
dota_hero_stats.groupby(['attack_type','primary_attr']).count()
# Out:
#                           Unnamed: 0  id  legs  localized_name  name  roles
# attack_type primary_attr
# Melee       agi                   19  19    19              19    19     19
#             int                    2   2     2               2     2      2
#             str                   35  35    35              35    35     35
# Ranged      agi                   18  18    18              18    18     18
#             int                   40  40    40              40    40     40
#             str                    3   3     3               3     3      3

# %%
accountancy = pd.read_csv('https://stepik.org/media/attachments/course/4852/accountancy.csv')

# %%
accountancy.head()
# Out:
#    Unnamed: 0 Executor Type  Salary
# 0           0     Pupa    D      63
# 1           1     Pupa    A     158
# 2           2     Pupa    D     194
# 3           3     Pupa    E     109
# 4           4    Loopa    E     184

# %%
accountancy.groupby(['Executor', 'Type'], as_index=False).sum('Salary')
# Out:
#    Executor Type  Unnamed: 0  Salary
# 0     Loopa    A          46      58
# 1     Loopa    B         144     871
# 2     Loopa    C         190     926
# 3     Loopa    D         223     964
# 4     Loopa    E         141     984
# 5     Loopa    F          40     476
# 6      Pupa    A          96     965
# 7      Pupa    B          41      77
# 8      Pupa    C          46     149
# 9      Pupa    D          56     586
# 10     Pupa    E          99     656
# 11     Pupa    F         103     545

# %%
accountancy.groupby(['Type','Executor']).mean().unstack()
# Out:
#          Unnamed: 0             Salary
# Executor      Loopa   Pupa       Loopa        Pupa
# Type
# A         46.000000  16.00   58.000000  160.833333
# B         24.000000  41.00  145.166667   77.000000
# C         31.666667  23.00  154.333333   74.500000
# D         31.857143  14.00  137.714286  146.500000
# E         23.500000  19.80  164.000000  131.200000
# F         20.000000  25.75  238.000000  136.250000

# %%
accountancy = pd.read_csv('http://stepik.org/media/attachments/course/4852/algae.csv')

# %%
accountancy
# Out:
#                 species        genus  group   sucrose    alanin   citrate  \
# 0     Fucus_vesiculosus        Fucus  brown  3.001472  3.711498  5.004262
# 1   Saccharina_japonica   Saccharina  brown  6.731070  1.255251  5.621499
# 2        Fucus_serratus        Fucus  brown  3.276870  0.346431  1.216767
# 3       Fucus_distichus        Fucus  brown  6.786996  6.641303  6.423606
# 4     Cladophora_fracta   Cladophora  green  3.861470  1.648450  6.940588
# 5   Cladophora_compacta   Cladophora  green  5.712284  3.461692  3.082826
# 6   Cladophora_gracilis   Cladophora  green  2.452623  6.881024  5.841520
# 7      Palmaria_palmata     Palmaria    red  0.704580  3.176440  5.573905
# 8  Saccharina_latissima   Saccharina  brown  1.636122  5.793163  1.071920
# 9   Ascophyllum_nodosum  Ascophyllum  brown  6.825467  0.875429  5.253527
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886
# ...

# %%
accountancy[['genus','alanin']][accountancy.genus == 'Fucus'].describe()
# Out:
#          alanin
# count  3.000000
# mean   3.566411
# std    3.149943
# min    0.346431
# 25%    2.028965
# 50%    3.711498
# 75%    5.176401
# max    6.641303

# %%
accountancy[].groupby(['group']).count()
# Out:
#        species  genus  sucrose  alanin  citrate  glucose  oleic_acid
# group
# brown        6      6        6       6        6        6           6
# green        3      3        3       3        3        3           3
# red          1      1        1       1        1        1           1
